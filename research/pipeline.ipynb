# %%
import os
os.chdir("../src")
# %pwd
# Out:
# '/home/jovyan/work/RussianNewsSentimentAnalysis/src'

# %%
from russian_news_sentiment_analysis.pipelines.pipeline import run
# Out:
# [2024-03-21 10:32:10,590: 148: numexpr.utils: INFO: utils:  Note: NumExpr detected 16 cores but "NUMEXPR_MAX_THREADS" not set, so enforcing safe limit of 8.]
# [2024-03-21 10:32:10,591: 160: numexpr.utils: INFO: utils:  NumExpr defaulting to 8 threads.]
# [2024-03-21 10:32:11,906: 15: pymorphy3.opencorpora_dict.wrapper: INFO: wrapper:  Loading dictionaries from /opt/conda/lib/python3.11/site-packages/pymorphy3_dicts_ru/data]
# [2024-03-21 10:32:11,954: 19: pymorphy3.opencorpora_dict.wrapper: INFO: wrapper:  format: 2.4, revision: 417150, updated: 2022-01-08T22:09:24.565962]
# [nltk_data] Downloading package stopwords to /home/jovyan/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to /home/jovyan/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package omw-1.4 to /home/jovyan/nltk_data...
# [nltk_data]   Package omw-1.4 is already up-to-date!
# ...

# %%
datasets_ids = [0, 1, 2, 3, 4, 5, 6, 7]
model_id = 0

for dataset_id in datasets_ids:
    
    run(dataset_id=dataset_id, model_id=model_id)

# %%
datasets_ids = [0, 1, 2, 3, 4, 5, 6, 7]
model_id = 1

for dataset_id in datasets_ids:
    
    run(dataset_id=dataset_id, model_id=model_id)
# Out:
# [2024-03-21 10:32:14,260: 33: logger: INFO: pipeline:  >>>>>>>>>>>> STARTING PROCESSING dataset with id 1 >>>>>>>>>>>>]
# [2024-03-21 10:32:17,624: 37: logger: INFO: pipeline:  >>>>>> SPARK SESSION HAS BEEN INITIALIZED >>>>>>]
# [2024-03-21 10:32:17,631: 75: logger: INFO: common:  yaml file: russian_news_sentiment_analysis/config/config.yaml loaded successfully]
# [2024-03-21 10:32:17,633: 46: logger: INFO: pipeline:  >>>>>> COMPONENTS HAVE BEEN INITIALIZED >>>>>>]
# [2024-03-21 10:32:17,642: 75: logger: INFO: common:  yaml file: /home/jovyan/work/RussianNewsSentimentAnalysis/src/russian_news_sentiment_analysis/params/datasets.yaml loaded successfully]
# [2024-03-21 10:32:17,646: 75: logger: INFO: common:  yaml file: /home/jovyan/work/RussianNewsSentimentAnalysis/src/russian_news_sentiment_analysis/params/models.yaml loaded successfully]
# ...
